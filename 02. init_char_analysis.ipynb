# %% [markdown]
# ## **3. Initial Characteristic Analysis**
# ---

# %% [markdown]
# Our goals are:
# - Bin every predictor
# - Find the weighted average of each bin (attribute) in the characteristic
# - Acquire IV for every attribute

# %% [markdown]
# #### **3.1 Characteristic Binning**
# ---

# %%
# Import library
import pandas as pd
import numpy as np

# Load the data configuration
import src.utils as utils

# %% [markdown]
# - For the train set, we first concat the predictors (X) & target (y) data.
# - Modify the configuration file to include those concatenated data paths.

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %%
def data_concat(type):
    """Function to concat the input (X) & output (y) data"""
    X = utils.load_pickle(CONFIG_DATA[f'{type}_path'][0])
    y = utils.load_pickle(CONFIG_DATA[f'{type}_path'][1])
    
    # Concatenate data X and y
    data = pd.concat((X, y),
                     axis = 1)

    # Validation dataset
    print(f'Shape of data:', data.shape)

    # Dump concatenated data
    utils.dump_pickle(data, CONFIG_DATA[f'data_{type}_path'])
   
    return data

# %%
data_train = data_concat(type='train')
data_train.head()
# Out:
# Shape of data: (5129, 23)
#        Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 4025  54.0     Doctor      114597.04            9366.753333
# 386   37.0   Engineer       18721.30            1684.108333
# 5446  53.0    Manager       41675.64            3451.970000
# 5391  17.0    Teacher       17291.27            1226.939167
# 587   16.0  Architect       63149.20            5121.433333
#
#       Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 4025                7.0              6.0            4.0          4.0
# 386                 4.0              5.0           28.0          3.0
# 5446                4.0              3.0           12.0          2.0
# 5391               10.0              9.0           20.0          8.0
# 587                 7.0             10.0           19.0          6.0
#
#        Type_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 4025   Student Loan                   28                     6.0
# 386   Mortgage Loan                   21                    11.0
# 5446  Personal Loan                    6                    10.0
# 5391  Mortgage Loan                   26                    15.0
# 587       Auto Loan                   20                    16.0
#
#       Changed_Credit_Limit  Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 4025                 10.54                   0.0       Good            926.18
# 386                   7.26                   5.0   Standard           2646.59
# 5446                  4.90                   2.0       Good           1181.64
# 5391                 -0.14                   8.0       Poor           4231.86
# 587                  27.02                   7.0       Poor           3656.46
#
#       Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 4025                 28.277461                  33                    No
# 386                  29.393327                  16                   Yes
# 5446                 32.509450                  28                    No
# 5391                 23.815207                  15                   Yes
# 587                  34.456617                   8                   Yes
#
#       Total_EMI_per_month  Amount_invested_monthly  \
# 4025           225.923762               774.659073
# 386             46.593546                47.968644
# 5446            53.796807               239.400348
# 5391           105.151792                82.676235
# 587            233.602177               119.261482
#
#                     Payment_Behaviour  Monthly_Balance  Credit_Score
# 4025   Low_spent_Large_value_payments       206.092498             0
# 386   High_spent_Small_value_payments       333.848643             0
# 5446  High_spent_Small_value_payments       311.999845             1
# 5391  Low_spent_Medium_value_payments       214.865889             0
# 587                            !@9#%8       419.279674             0

# %% [markdown]
# - After that, we bin the combined data.
# - Since numerical columns already have a binning function, categorical columns do not require one.
# - Modify the configuration file so that:
#     - The names of the numerical columns
#     - The names of the categorical columns
#     - The names of the missing columns
#     - The quantity of bins
#     - The binned train set's path

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %%
# Make a function that allows the numerical predictor to be binned.
def define_num_binning(data, predictor_label, num_of_bins):
    """Create function to binning the numerical predictor"""
    # Make a new column with the binned predictor in it.
    data[predictor_label + "_bin"] = pd.qcut(data[predictor_label],
                                             q = num_of_bins)

    return data

# %%
def data_bin(type):
    """Create function to binning the numerical and missing data"""
    # Load the concatenated data
    data = utils.load_pickle(CONFIG_DATA[f'data_{type}_path'])

    # Bin the numerical columns
    num_columns = CONFIG_DATA['num_columns']
    num_of_bins = CONFIG_DATA['num_of_bins']

    for column in num_columns:
        data_binned = define_num_binning(data = data,
                                         predictor_label = column,
                                         num_of_bins = num_of_bins)

    # Bin missing values
    missing_columns = CONFIG_DATA['missing_columns']

    for column in missing_columns:
        # Incorporate the 'Missing' category to substitute the absent values.
        data_binned[column] = (data_binned[column]
                                    .cat
                                    .add_categories('Missing'))

        # Replace missing values with category 'Missing'
        data_binned[column].fillna(value = 'Missing',
                                   inplace = True)

    # Validate
    print(f"The original data shape : ", data.shape)
    print(f"The binned data shape  : ", data_binned.shape)

    # Dump binned data
    utils.dump_pickle(data_binned, CONFIG_DATA[f'data_{type}_binned_path'])
        
    return data_binned

# %%
train_binned = data_bin(type='train')
train_binned.head()
# Out:
# The original data shape :  (5129, 40)
# The binned data shape  :  (5129, 40)
#        Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 4025  54.0     Doctor      114597.04            9366.753333
# 386   37.0   Engineer       18721.30            1684.108333
# 5446  53.0    Manager       41675.64            3451.970000
# 5391  17.0    Teacher       17291.27            1226.939167
# 587   16.0  Architect       63149.20            5121.433333
#
#       Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 4025                7.0              6.0            4.0          4.0
# 386                 4.0              5.0           28.0          3.0
# 5446                4.0              3.0           12.0          2.0
# 5391               10.0              9.0           20.0          8.0
# 587                 7.0             10.0           19.0          6.0
#
#        Type_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 4025   Student Loan                   28                     6.0
# 386   Mortgage Loan                   21                    11.0
# 5446  Personal Loan                    6                    10.0
# 5391  Mortgage Loan                   26                    15.0
# 587       Auto Loan                   20                    16.0
#
#       Changed_Credit_Limit  Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 4025                 10.54                   0.0       Good            926.18
# 386                   7.26                   5.0   Standard           2646.59
# 5446                  4.90                   2.0       Good           1181.64
# 5391                 -0.14                   8.0       Poor           4231.86
# 587                  27.02                   7.0       Poor           3656.46
#
#       Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 4025                 28.277461                  33                    No
# 386                  29.393327                  16                   Yes
# 5446                 32.509450                  28                    No
# 5391                 23.815207                  15                   Yes
# 587                  34.456617                   8                   Yes
#
#       Total_EMI_per_month  Amount_invested_monthly  \
# 4025           225.923762               774.659073
# 386             46.593546                47.968644
# 5446            53.796807               239.400348
# 5391           105.151792                82.676235
# 587            233.602177               119.261482
#
#                     Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 4025   Low_spent_Large_value_payments       206.092498             0
# 386   High_spent_Small_value_payments       333.848643             0
# 5446  High_spent_Small_value_payments       311.999845             1
# 5391  Low_spent_Medium_value_payments       214.865889             0
# 587                            !@9#%8       419.279674             0
#
#              Age_bin       Annual_Income_bin Num_of_Loan_bin  \
# 4025    (41.0, 55.0]  (70112.78, 23658189.0]      (2.0, 4.0]
# 386     (33.0, 41.0]    (7005.929, 18921.78]      (2.0, 4.0]
# 5446    (41.0, 55.0]    (36346.13, 70112.78]    (0.999, 2.0]
# 5391  (13.999, 24.0]    (7005.929, 18921.78]     (6.0, 10.0]
# 587   (13.999, 24.0]    (36346.13, 70112.78]      (4.0, 6.0]
#
#      Num_of_Delayed_Payment_bin Outstanding_Debt_bin  \
# 4025              (-3.001, 9.0]    (603.87, 1237.12]
# 386                 (9.0, 14.0]   (2094.49, 4998.07]
# 5446                (9.0, 14.0]    (603.87, 1237.12]
# 5391               (14.0, 18.0]   (2094.49, 4998.07]
# 587                (14.0, 18.0]   (2094.49, 4998.07]
#
#      Monthly_Inhand_Salary_bin Num_Credit_Inquiries_bin  \
# 4025      (5796.608, 15167.18]            (-0.001, 2.0]
# 386       (1587.629, 3012.665]               (4.0, 8.0]
# 5446      (3012.665, 5796.608]            (-0.001, 2.0]
# 5391       (319.555, 1587.629]               (4.0, 8.0]
# 587       (3012.665, 5796.608]               (4.0, 8.0]
#
#      Credit_Utilization_Ratio_bin Total_EMI_per_month_bin  \
# 4025             (28.142, 32.225]      (161.488, 82122.0]
# 386              (28.142, 32.225]        (39.269, 75.585]
# 5446             (32.225, 36.298]        (39.269, 75.585]
# 5391             (21.705, 28.142]       (75.585, 161.488]
# 587              (32.225, 36.298]      (161.488, 82122.0]
#
#      Num_Bank_Accounts_bin Num_Credit_Card_bin Interest_Rate_bin  \
# 4025            (6.0, 7.0]          (4.0, 6.0]      (0.999, 8.0]
# 386          (-0.001, 4.0]          (4.0, 6.0]      (21.0, 34.0]
# 5446         (-0.001, 4.0]        (0.999, 4.0]       (8.0, 15.0]
# 5391           (7.0, 10.0]         (7.0, 10.0]      (15.0, 21.0]
# 587             (6.0, 7.0]         (7.0, 10.0]      (15.0, 21.0]
#
#      Delay_from_due_date_bin Amount_invested_monthly_bin Monthly_Balance_bin  \
# 4025            (19.0, 29.0]          (247.885, 10000.0]    (0.907, 267.848]
# 386             (19.0, 29.0]            (-0.001, 71.415]  (330.162, 454.617]
# 5446          (-4.001, 10.0]           (129.42, 247.885]  (267.848, 330.162]
# 5391            (19.0, 29.0]            (71.415, 129.42]    (0.907, 267.848]
# 587             (19.0, 29.0]            (71.415, 129.42]  (330.162, 454.617]
#
#      Changed_Credit_Limit_bin Credit_History_Age_bin
# 4025            (9.74, 15.44]           (28.0, 41.0]
# 386              (5.78, 9.74]           (15.0, 21.0]
# 5446           (-6.391, 5.78]           (21.0, 28.0]
# 5391           (-6.391, 5.78]         (-0.001, 15.0]
# 587            (15.44, 34.81]         (-0.001, 15.0]

# %%
train_binned.isnull().sum()
# Out:
# Age                             108
# Occupation                        0
# Annual_Income                     0
# Monthly_Inhand_Salary             0
# Num_Bank_Accounts                76
# Num_Credit_Card                 115
# Interest_Rate                   111
# Num_of_Loan                      30
# Type_of_Loan                      0
# Delay_from_due_date               0
# Num_of_Delayed_Payment           33
# Changed_Credit_Limit              0
# Num_Credit_Inquiries             69
# Credit_Mix                        0
# Outstanding_Debt                  0
# Credit_Utilization_Ratio          0
# Credit_History_Age                0
# Payment_of_Min_Amount             0
# Total_EMI_per_month               0
# Amount_invested_monthly           0
# Payment_Behaviour                 0
# Monthly_Balance                   0
# Credit_Score                      0
# Age_bin                           0
# Annual_Income_bin                 0
# Num_of_Loan_bin                   0
# Num_of_Delayed_Payment_bin        0
# Outstanding_Debt_bin              0
# Monthly_Inhand_Salary_bin         0
# Num_Credit_Inquiries_bin          0
# Credit_Utilization_Ratio_bin      0
# Total_EMI_per_month_bin           0
# Num_Bank_Accounts_bin             0
# Num_Credit_Card_bin               0
# Interest_Rate_bin                 0
# Delay_from_due_date_bin           0
# Amount_invested_monthly_bin       0
# Monthly_Balance_bin               0
# Changed_Credit_Limit_bin          0
# Credit_History_Age_bin            0
# dtype: int64

# %% [markdown]
# ### **3.2 WoE and IV**
# ---
#
# - To evaluate each trait's strength separately as a predictor of credit performance.
#     - Modify the configuration file so that
#     - Path for a crosstab list
#     - Table path for WOE - Table path for IV

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %%
def define_crosstab_list():
    """Create the crosstab list (contingency table) needed for the computation of WOE and IV. In training data only"""
    # load the binned train data
    data_train_binned = utils.load_pickle(CONFIG_DATA['data_train_binned_path'])

    # the target variable is loaded (The target variable will be used to summarize.)
    target_variable = CONFIG_DATA['target_variable']

    # Repeat over the numerical columns.
    crosstab_num = []
    num_columns = CONFIG_DATA['num_columns']
    for column in num_columns:
        # Establish a contigency table.
        crosstab = pd.crosstab(data_train_binned[column + "_bin"],
                               data_train_binned[target_variable],
                               margins = True)

        # Append to the list
        crosstab_num.append(crosstab)

    # Repeat with the category columns.
    crosstab_cat = []
    cat_columns = CONFIG_DATA['cat_columns']
    for column in cat_columns:
        # Establish a contigency table.
        crosstab = pd.crosstab(data_train_binned[column],
                               data_train_binned[target_variable],
                               margins = True)

        # Append to the list
        crosstab_cat.append(crosstab)

    # Put all two in a crosstab_list
    crosstab_list = crosstab_num + crosstab_cat

    # Validate the crosstab_list
    print('Count of num bin : ', [bin.shape for bin in crosstab_num])
    print('Count of cat bin : ', [bin.shape for bin in crosstab_cat])

    # Dump the result
    utils.dump_pickle(crosstab_list, CONFIG_DATA['crosstab_list_path'])

    return crosstab_list

# %%
crosstab_list = define_crosstab_list()
crosstab_list[0]
# Out:
# Count of num bin :  [(6, 3), (5, 3), (6, 3), (6, 3), (5, 3), (5, 3), (6, 3), (5, 3), (5, 3), (6, 3), (6, 3), (6, 3), (5, 3), (5, 3), (5, 3), (5, 3), (5, 3)]
# Count of cat bin :  [(17, 3), (9, 3), (4, 3), (4, 3), (8, 3)]
# Credit_Score       0     1   All
# Age_bin
# (13.999, 24.0]   874   460  1334
# (24.0, 33.0]     803   503  1306
# (33.0, 41.0]     755   456  1211
# (41.0, 55.0]     513   657  1170
# Missing           60    48   108
# All             3005  2124  5129

# %%
crosstab_list[10]
# Out:
# Credit_Score            0     1   All
# Num_Credit_Card_bin
# (0.999, 4.0]          557   988  1545
# (4.0, 6.0]           1059   706  1765
# (6.0, 7.0]            507   351   858
# (7.0, 10.0]           815    31   846
# Missing                67    48   115
# All                  3005  2124  5129

# %%
def WOE_and_IV():
    """Obtain the IV and WoE."""
    # Load the crosstab list
    crosstab_list = utils.load_pickle(CONFIG_DATA['crosstab_list_path'])

    # Establish initial IV and WoE storage
    WOE_list, IV_list = [], []
    
    # Execute the computation for every crosstab list.
    for crosstab in crosstab_list:
        # Determine the WoE and IV.
        crosstab['p_good'] = crosstab[1]/crosstab[1]['All']                                 # Calculate % Good
        crosstab['p_bad'] = crosstab[0]/crosstab[0]['All']                                  # Calculate % Bad
        crosstab['WOE'] = np.log(crosstab['p_good']/crosstab['p_bad'])                      # Calculate the WOE
        crosstab['contribution'] = (crosstab['p_good']-crosstab['p_bad'])*crosstab['WOE']   # Calculate the contribution value for IV
        IV = crosstab['contribution'][:-1].sum()                                            # Calculate the IV
        
        # Append to list
        WOE_list.append(crosstab)

        add_IV = {'Characteristic': crosstab.index.name, 
                  'Information Value': IV}
        IV_list.append(add_IV)


    # CREATE WOE TABLE
    # Make the first table outlining the WOE values.
    WOE_table = pd.DataFrame({'Characteristic': [],
                              'Attribute': [],
                              'WOE': []})
    for i in range(len(crosstab_list)):
        # Crosstab definition and index reset
        crosstab = crosstab_list[i].reset_index()

        # Keep the trait name saved.
        char_name = crosstab.columns[0]

        # Utilize just the attribute name and its WOE value in two columns.
        # Remove the final row (average/total WOE).
        crosstab = crosstab.iloc[:-1, [0,-2]]
        crosstab.columns = ['Attribute', 'WOE']

        # Put the name of the characteristic in a column.
        crosstab['Characteristic'] = char_name

        WOE_table = pd.concat((WOE_table, crosstab), 
                                axis = 0)

        # Reposition the column.
        WOE_table.columns = ['Characteristic',
                            'Attribute',
                            'WOE']
    

    # CREATE IV TABLE
    # Make the IV initial table.
    IV_table = pd.DataFrame({'Characteristic': [],
                             'Information Value' : []})
    IV_table = pd.DataFrame(IV_list)

    # Describe each characteristic's capacity for prediction.
    strength = []

    # Assign the rule of thumb regarding IV
    for iv in IV_table['Information Value']:
        if iv < 0.02:
            strength.append('Unpredictive')
        elif iv >= 0.02 and iv < 0.1:
            strength.append('Weak')
        elif iv >= 0.1 and iv < 0.3:
            strength.append('Medium')
        else:
            strength.append('Strong')

    # Assign each characteristic a strength.
    IV_table = IV_table.assign(Strength = strength)

    # Table sorted according to IV values
    IV_table = IV_table.sort_values(by='Information Value')
    
    # Validation
    print('WOE table shape : ', WOE_table.shape)
    print('IV table shape  : ', IV_table.shape)

    # Dump data
    utils.dump_pickle(WOE_table, CONFIG_DATA['WOE_table_path'])
    utils.dump_pickle(IV_table, CONFIG_DATA['IV_table_path']) 

    return WOE_table, IV_table

# %%
WOE_table, IV_table = WOE_and_IV()
# Out:
# WOE table shape :  (112, 3)
# IV table shape  :  (22, 3)

# %%
WOE_table
# Out:
#                   Characteristic                         Attribute       WOE
# 0                        Age_bin                    (13.999, 24.0] -0.291272
# 1                        Age_bin                      (24.0, 33.0] -0.160496
# 2                        Age_bin                      (33.0, 41.0] -0.189201
# 3                        Age_bin                      (41.0, 57.0]  0.658328
# 4                        Age_bin                           Missing  0.084612
# 0              Annual_Income_bin              (7005.929, 18976.46] -0.758924
# 1              Annual_Income_bin              (18976.46, 35991.91]  0.083370
# 2              Annual_Income_bin              (35991.91, 70256.94] -0.074114
# 3              Annual_Income_bin            (70256.94, 23658189.0]  0.658361
# 0                Num_of_Loan_bin                      (0.999, 2.0]  0.656399
# 1                Num_of_Loan_bin                        (2.0, 4.0]  0.603696
# 2                Num_of_Loan_bin                        (4.0, 6.0] -1.266276
# 3                Num_of_Loan_bin                       (6.0, 10.0] -1.493573
# 4                Num_of_Loan_bin                           Missing -0.080468
# 0     Num_of_Delayed_Payment_bin                     (-3.001, 9.0]  1.131931
# 1     Num_of_Delayed_Payment_bin                       (9.0, 14.0]  0.342118
# 2     Num_of_Delayed_Payment_bin                      (14.0, 19.0] -0.501255
# 3     Num_of_Delayed_Payment_bin                     (19.0, 887.0] -1.613800
# 4     Num_of_Delayed_Payment_bin                           Missing  0.078712
# 0           Outstanding_Debt_bin                    (0.229, 614.6]  0.969615
# 1           Outstanding_Debt_bin                  (614.6, 1250.01]  0.937676
# 2           Outstanding_Debt_bin                (1250.01, 2086.83] -0.472983
# 3           Outstanding_Debt_bin                (2086.83, 4998.07] -2.474733
# 0      Monthly_Inhand_Salary_bin                (303.644, 1587.71] -0.713546
# 1      Monthly_Inhand_Salary_bin                 (1587.71, 2992.9]  0.019590
# 2      Monthly_Inhand_Salary_bin                (2992.9, 5762.593] -0.083905
# 3      Monthly_Inhand_Salary_bin              (5762.593, 15167.18]  0.696836
# 0       Num_Credit_Inquiries_bin                     (-0.001, 2.0]  1.132792
# 1       Num_Credit_Inquiries_bin                        (2.0, 5.0]  0.830093
# 2       Num_Credit_Inquiries_bin                        (5.0, 8.0] -0.942439
# 3       Num_Credit_Inquiries_bin                       (8.0, 12.0] -2.845205
# 4       Num_Credit_Inquiries_bin                           Missing  0.221813
# 0   Credit_Utilization_Ratio_bin                  (21.317, 28.076] -0.227982
# 1   Credit_Utilization_Ratio_bin                  (28.076, 32.119]  0.038788
# 2   Credit_Utilization_Ratio_bin                  (32.119, 36.233]  0.025996
# 3   Credit_Utilization_Ratio_bin                  (36.233, 49.565]  0.156071
# 0        Total_EMI_per_month_bin       (4.864999999999999, 39.917]  0.110495
# 1        Total_EMI_per_month_bin                  (39.917, 75.868] -0.057839
# 2        Total_EMI_per_month_bin                  (75.868, 159.81]  0.061114
# 3        Total_EMI_per_month_bin                 (159.81, 82122.0] -0.116694
# 0          Num_Bank_Accounts_bin                     (-0.001, 4.0]  0.973896
# 1          Num_Bank_Accounts_bin                        (4.0, 6.0]  0.002291
# 2          Num_Bank_Accounts_bin                        (6.0, 7.0] -0.751636
# 3          Num_Bank_Accounts_bin                       (7.0, 10.0] -1.333955
# 4          Num_Bank_Accounts_bin                           Missing  0.346976
# 0            Num_Credit_Card_bin                      (0.999, 4.0]  0.994945
# 1            Num_Credit_Card_bin                        (4.0, 6.0] -0.081282
# 2            Num_Credit_Card_bin                        (6.0, 7.0] -0.118106
# 3            Num_Credit_Card_bin                       (7.0, 10.0] -2.958688
# 4            Num_Credit_Card_bin                           Missing  0.155085
# 0              Interest_Rate_bin                      (0.999, 8.0]  1.208767
# 1              Interest_Rate_bin                       (8.0, 15.0]  0.676874
# 2              Interest_Rate_bin                      (15.0, 21.0] -0.681693
# 3              Interest_Rate_bin                      (21.0, 34.0] -2.897350
# 4              Interest_Rate_bin                           Missing  0.226832
# 0        Delay_from_due_date_bin                    (-4.001, 10.0]  1.253798
# 1        Delay_from_due_date_bin                      (10.0, 19.0]  0.417020
# 2        Delay_from_due_date_bin                      (19.0, 29.0] -0.475728
# 3        Delay_from_due_date_bin                      (29.0, 67.0] -2.004399
# 0    Amount_invested_monthly_bin                  (-0.001, 70.221] -0.511108
# 1    Amount_invested_monthly_bin                 (70.221, 129.712]  0.006759
# 2    Amount_invested_monthly_bin                (129.712, 250.762]  0.108726
# 3    Amount_invested_monthly_bin                (250.762, 10000.0]  0.356337
# 0            Monthly_Balance_bin     (2.4770000000000003, 266.428] -0.541113
# 1            Monthly_Balance_bin                (266.428, 325.913] -0.404072
# 2            Monthly_Balance_bin                (325.913, 446.675]  0.102395
# 3            Monthly_Balance_bin               (446.675, 1552.946]  0.774592
# 0       Changed_Credit_Limit_bin                    (-5.011, 5.71]  0.429514
# 1       Changed_Credit_Limit_bin                      (5.71, 9.74]  0.212819
# 2       Changed_Credit_Limit_bin                     (9.74, 15.38]  0.190161
# 3       Changed_Credit_Limit_bin                    (15.38, 35.84] -0.988419
# 0         Credit_History_Age_bin                    (-0.001, 14.0] -1.521283
# 1         Credit_History_Age_bin                      (14.0, 21.0] -0.295198
# 2         Credit_History_Age_bin                      (21.0, 28.0]  0.510803
# 3         Credit_History_Age_bin                      (28.0, 41.0]  1.100748
# 0                     Occupation                        Accountant -0.070942
# 1                     Occupation                         Architect  0.034426
# 2                     Occupation                         Developer -0.036348
# 3                     Occupation                            Doctor -0.000022
# 4                     Occupation                          Engineer -0.064029
# 5                     Occupation                      Entrepreneur -0.018323
# 6                     Occupation                        Journalist  0.046319
# 7                     Occupation                            Lawyer  0.201794
# 8                     Occupation                           Manager  0.029217
# 9                     Occupation                          Mechanic -0.066457
# 10                    Occupation                     Media_Manager  0.209259
# 11                    Occupation                          Musician -0.129948
# 12                    Occupation                         Scientist -0.086819
# 13                    Occupation                           Teacher  0.001475
# 14                    Occupation                            Writer -0.029833
# 15                    Occupation                           _______ -0.044883
# 0                   Type_of_Loan                         Auto Loan  0.052109
# 1                   Type_of_Loan               Credit-Builder Loan  0.168365
# 2                   Type_of_Loan           Debt Consolidation Loan  0.410035
# 3                   Type_of_Loan                  Home Equity Loan  0.723786
# 4                   Type_of_Loan                     Mortgage Loan -0.399961
# 5                   Type_of_Loan                       Payday Loan  1.077864
# 6                   Type_of_Loan                     Personal Loan  0.576900
# 7                   Type_of_Loan                      Student Loan -0.019955
# 0                     Credit_Mix                              Good  2.135363
# 1                     Credit_Mix                              Poor -1.875242
# 2                     Credit_Mix                          Standard -0.063738
# 0          Payment_of_Min_Amount                                NM  0.037336
# 1          Payment_of_Min_Amount                                No  1.373788
# 2          Payment_of_Min_Amount                               Yes -0.871675
# 0              Payment_Behaviour                            !@9#%8  0.072033
# 1              Payment_Behaviour   High_spent_Large_value_payments  0.226888
# 2              Payment_Behaviour  High_spent_Medium_value_payments  0.095933
# 3              Payment_Behaviour   High_spent_Small_value_payments -0.003226
# 4              Payment_Behaviour    Low_spent_Large_value_payments  0.057169
# 5              Payment_Behaviour   Low_spent_Medium_value_payments  0.045274
# 6              Payment_Behaviour    Low_spent_Small_value_payments -0.283317

# %%
IV_table
# Out:
#                   Characteristic  Information Value      Strength
# 7   Credit_Utilization_Ratio_bin           0.005922  Unpredictive
# 17                    Occupation           0.007241  Unpredictive
# 8        Total_EMI_per_month_bin           0.011992  Unpredictive
# 21             Payment_Behaviour           0.033472          Weak
# 13   Amount_invested_monthly_bin           0.083092          Weak
# 0                        Age_bin           0.114035        Medium
# 18                  Type_of_Loan           0.116137        Medium
# 5      Monthly_Inhand_Salary_bin           0.233616        Medium
# 1              Annual_Income_bin           0.235637        Medium
# 14           Monthly_Balance_bin           0.238552        Medium
# 15      Changed_Credit_Limit_bin           0.281584        Medium
# 9          Num_Bank_Accounts_bin           0.746623        Strong
# 3     Num_of_Delayed_Payment_bin           0.773799        Strong
# 2                Num_of_Loan_bin           0.809417        Strong
# 16        Credit_History_Age_bin           0.848206        Strong
# 20         Payment_of_Min_Amount           0.899237        Strong
# 10           Num_Credit_Card_bin           1.008591        Strong
# 12       Delay_from_due_date_bin           1.092280        Strong
# 4           Outstanding_Debt_bin           1.405628        Strong
# 11             Interest_Rate_bin           1.593648        Strong
# 6       Num_Credit_Inquiries_bin           1.634212        Strong
# 19                    Credit_Mix           1.808356        Strong
