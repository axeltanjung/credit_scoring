# %% [markdown]
# ## A. Data Preparation & Data Preprocessing
# -----------------------------------------------------------------

# %% [markdown]
# ### 1. Read Data

# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load config from utils file
import src.utils as utils

# %% [markdown]
# To import and dump data, create a configuration file.

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %% [markdown]
# Create open_data() function to open the dataset

# %%
def open_data():
    """Import data and dump data"""

    # Import data
    path_data = CONFIG_DATA['raw_data_path']
    data = pd.read_csv(path_data)

    # Create data validation for data shape
    print("Shape of data    :", data.shape)

    # Dump the dataset to pickle format
    path_dump = CONFIG_DATA['data_path']
    utils.dump_pickle(data, path_dump)

    return data

# %%
data = open_data()
data.head()
# Out:
# Shape of data    : (7328, 23)
#     Age    Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0  23.0     Scientist       19114.12            1824.843333
# 1  28.0       _______       34847.84            3037.986667
# 2  34.0       _______      143162.64           12187.220000
# 3  54.0  Entrepreneur       30689.89            2612.490833
# 4  33.0        Lawyer      131313.40           11242.783330
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                2.0              4.0            6.0          1.0
# 2                1.0              5.0            8.0          3.0
# 3                2.0              5.0            4.0          1.0
# 4                0.0              1.0            8.0          2.0
#
#           Type_of_Loan  Delay_from_due_date  ...  Credit_Mix  \
# 0            Auto Loan                    3  ...        Good
# 1  Credit-Builder Loan                    3  ...        Good
# 2            Auto Loan                    5  ...        Good
# 3        Personal Loan                    0  ...        Good
# 4        Mortgage Loan                    0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                 26.822620                 23
# 1            605.03                 24.464031                 33
# 2           1303.01                 28.616735                 26
# 3            632.46                 26.544229                 20
# 4            352.16                 32.200509                 37
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                     No            49.574949                80.415295
# 1                     No            18.816215               104.291825
# 2                     No           246.992320               168.413703
# 3                     No            16.415452                81.228859
# 4                     NM           137.644605               378.171253
#
#                   Payment_Behaviour  Monthly_Balance  Credit_Score
# 0   High_spent_Small_value_payments       312.494089             1
# 1    Low_spent_Small_value_payments       470.690627             1
# 2                            !@9#%8      1043.315978             1
# 3    Low_spent_Large_value_payments       433.604773             1
# 4  High_spent_Medium_value_payments       858.462474             1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 2. Splitting the Sample

# %% [markdown]
# Split the input and output data and dump it
# -Update the configuration file with the following information:
# - The path for the input and output data
# - The name of the output variable
# - The names of the input columns

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %%
def input_output_splitting():
    "Function to split the input and output as predictors and target variable"

    # Load dataset
    data_path = CONFIG_DATA['data_path']
    data = utils.load_pickle(data_path)

    # Define target variable (y)
    target_var = CONFIG_DATA['target_variable']
    y = data[target_var]

    # Define predictors variable (X)
    X = data.drop(columns = [target_var],
                  axis = 1)
    
    # Create validation to splitting X and y
    print('Shape of y :', y.shape)
    print('Shape of X :', X.shape)

    # Dump the output
    dump_path_predictors = CONFIG_DATA['predictors_set_path']
    utils.dump_pickle(X, dump_path_predictors)

    dump_path_target = CONFIG_DATA['target_set_path']
    utils.dump_pickle(y, dump_path_target)

    return X, y

# %%
X, y = input_output_splitting()
# Out:
# Shape of y : (7328,)
# Shape of X : (7328, 22)

# %%
X.head()
# Out:
#     Age    Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0  23.0     Scientist       19114.12            1824.843333
# 1  28.0       _______       34847.84            3037.986667
# 2  34.0       _______      143162.64           12187.220000
# 3  54.0  Entrepreneur       30689.89            2612.490833
# 4  33.0        Lawyer      131313.40           11242.783330
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                2.0              4.0            6.0          1.0
# 2                1.0              5.0            8.0          3.0
# 3                2.0              5.0            4.0          1.0
# 4                0.0              1.0            8.0          2.0
#
#           Type_of_Loan  Delay_from_due_date  ...  Num_Credit_Inquiries  \
# 0            Auto Loan                    3  ...                   4.0
# 1  Credit-Builder Loan                    3  ...                   2.0
# 2            Auto Loan                    5  ...                   3.0
# 3        Personal Loan                    0  ...                   4.0
# 4        Mortgage Loan                    0  ...                   2.0
#
#    Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  Credit_History_Age  \
# 0        Good            809.98                26.822620                  23
# 1        Good            605.03                24.464031                  33
# 2        Good           1303.01                28.616735                  26
# 3        Good            632.46                26.544229                  20
# 4        Good            352.16                32.200509                  37
#
#    Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                     No            49.574949               80.415295
# 1                     No            18.816215              104.291825
# 2                     No           246.992320              168.413703
# 3                     No            16.415452               81.228859
# 4                     NM           137.644605              378.171253
#
#                   Payment_Behaviour  Monthly_Balance
# 0   High_spent_Small_value_payments       312.494089
# 1    Low_spent_Small_value_payments       470.690627
# 2                            !@9#%8      1043.315978
# 3    Low_spent_Large_value_payments       433.604773
# 4  High_spent_Medium_value_payments       858.462474
#
# [5 rows x 22 columns]

# %% [markdown]
# The training and testing sets for each predictor (X) and response (y) should then be divided.
# - To partition the sample using stratify according to the percentage of response y, set `{stratify = y}`.
# - To hold 30% of the sample as a testing set, specify `test_size = 0.3`.
# - Adjust `{random_state = 42}` to ensure consistency.

# %%
# Import library 
from sklearn.model_selection import train_test_split

# %% [markdown]
# Update the configuration file with the test size and the train and test data paths.

# %%
CONFIG_DATA = utils.load_config()
CONFIG_DATA
# Out:
# {'raw_data_path': 'data/raw/credit_dataset.csv',
#  'data_path': 'data/output/data.pkl',
#  'predictors_set_path': 'data/output/predictors.pkl',
#  'target_set_path': 'data/output/target.pkl',
#  'train_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'test_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'data_train_path': 'data/output/data_train.pkl',
#  'data_train_binned_path': 'data/output/data_train_binned.pkl',
#  'crosstab_list_path': 'data/output/crosstab_list.pkl',
#  'WOE_table_path': 'data/output/WOE_table.pkl',
#  'IV_table_path': 'data/output/IV_table.pkl',
#  'WOE_map_dict_path': 'data/output/WOE_map_dict.pkl',
#  'X_train_woe_path': 'data/output/X_train_woe.pkl',
#  'target_variable': 'Credit_Score',
#  'test_size': 0.3,
#  'num_columns': ['Age',
#   'Annual_Income',
#   'Num_of_Loan',
#   'Num_of_Delayed_Payment',
#   'Outstanding_Debt',
#   'Monthly_Inhand_Salary',
#   'Num_Credit_Inquiries',
#   'Credit_Utilization_Ratio',
#   'Total_EMI_per_month',
#   'Num_Bank_Accounts',
#   'Num_Credit_Card',
#   'Interest_Rate',
#   'Delay_from_due_date',
#   'Amount_invested_monthly',
#   'Monthly_Balance',
#   'Changed_Credit_Limit',
#   'Credit_History_Age'],
#  'cat_columns': ['Occupation',
#   'Type_of_Loan',
#   'Credit_Mix',
#   'Payment_of_Min_Amount',
#   'Payment_Behaviour'],
#  'missing_columns': ['Age_bin',
#   'Num_Bank_Accounts_bin',
#   'Num_Credit_Card_bin',
#   'Interest_Rate_bin',
#   'Num_of_Loan_bin',
#   'Num_of_Delayed_Payment_bin',
#   'Num_Credit_Inquiries_bin',
#   'Monthly_Balance_bin'],
#  'num_of_bins': 4,
#  'num_of_cv': 10,
#  'scoring': 'recall',
#  'forward_models_path': 'models/forward_models.pkl',
#  'best_predictors_path': 'models/best_predictors_path.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_model_summary_path': 'models/best_model_summary.pkl',
#  'pdo': 20,
#  'score_ref': 300,
#  'odds_ref': 30,
#  'scorecards_path': 'models/scorecards.pkl',
#  'points_map_dict_path': 'models/points_map_dict.pkl',
#  'X_points_path': 'models/X_points.pkl',
#  'X_train_points_path': 'models/X_train_points.pkl',
#  'score_path': 'models/score_path.pkl',
#  'cutoff_score': 150,
#  'columns_': ['person_age_bin',
#   'person_income_bin',
#   'person_emp_length_bin',
#   'loan_amnt_bin',
#   'loan_int_rate_bin',
#   'loan_percent_income_bin',
#   'cb_person_cred_hist_length_bin',
#   'person_home_ownership',
#   'loan_intent',
#   'loan_grade',
#   'cb_person_default_on_file']}

# %%
def train_test_splitting():
    """Function to split train & test, after that dump the data"""
    
    # Load the X and y dataset
    X = utils.load_pickle(CONFIG_DATA['predictors_set_path'])
    y = utils.load_pickle(CONFIG_DATA['target_set_path'])

    # Spliting the dataset
    X_train, X_test, y_train, y_test = train_test_split(X,
                                                        y,
                                                        stratify = y,
                                                        test_size = CONFIG_DATA['test_size'],
                                                        random_state = 42)
    # Validation of splitting data
    print('X_train shape :', X_train.shape)
    print('y_train shape :', y_train.shape)
    print('X_test shape  :', X_test.shape)
    print('y_test shape  :', y_test.shape)

    # Dump data
    utils.dump_pickle(X_train, CONFIG_DATA['train_path'][0])
    utils.dump_pickle(y_train, CONFIG_DATA['train_path'][1])
    utils.dump_pickle(X_test, CONFIG_DATA['test_path'][0])
    utils.dump_pickle(y_test, CONFIG_DATA['test_path'][1])

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_splitting()
# Out:
# X_train shape : (5129, 22)
# y_train shape : (5129,)
# X_test shape  : (2199, 22)
# y_test shape  : (2199,)

# %%
X_train.nunique()
# Out:
# Age                           42
# Occupation                    16
# Annual_Income               5127
# Monthly_Inhand_Salary       5128
# Num_Bank_Accounts             11
# Num_Credit_Card               10
# Interest_Rate                 34
# Num_of_Loan                   10
# Type_of_Loan                   8
# Delay_from_due_date           71
# Num_of_Delayed_Payment        40
# Changed_Credit_Limit        2150
# Num_Credit_Inquiries          13
# Credit_Mix                     3
# Outstanding_Debt            5075
# Credit_Utilization_Ratio    5129
# Credit_History_Age            42
# Payment_of_Min_Amount          3
# Total_EMI_per_month         5129
# Amount_invested_monthly     4878
# Payment_Behaviour              7
# Monthly_Balance             5129
# dtype: int64
